# %%
# Data manipulation
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import *
from sklearn.linear_model import LinearRegression
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import GridSearchCV

import xgboost as xgb
from xgboost import XGBRegressor
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression

from lightgbm import LGBMClassifier
from lightgbm import LGBMRegressor
from lightgbm import plot_importance

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor

import optuna

# %%
train_x = pd.DataFrame(pd.read_csv("C:/Users/yjs49/Desktop/ecar_EDA/imputation/탄소배출/탄소배출_0108.csv"))
train_y = pd.DataFrame(pd.read_csv("C:/Users/yjs49/Desktop/ecar_EDA/imputation/탄소배출/탄소배출_0912.csv"))

guro_x = pd.DataFrame(pd.read_csv("C:/Users/yjs49/Desktop/ecar_EDA/imputation/탄소배출/구로구_210108.csv"))
guro_y = pd.DataFrame(pd.read_csv("C:/Users/yjs49/Desktop/ecar_EDA/imputation/탄소배출/구로구_210912.csv"))

# %%
train_x
# Out:
#        행정동          1월가스        1월온실가스          2월가스        2월온실가스  \
# 0      소공동  3.161366e+06   6886.390826  2.606075e+06   5676.803770
# 1      회현동  2.368467e+06   5159.223772  1.994571e+06   4344.767323
# 2       명동  4.818737e+06  10496.636373  4.196608e+06   9141.454669
# 3       필동  9.091701e+05   1980.441908  8.868064e+05   1931.727112
# 4      장충동  1.353651e+06   2948.652858  1.372374e+06   2989.436261
# ...    ...           ...           ...           ...           ...
# 1631   세곡동  1.283392e+06   2795.607248  1.179694e+06   2569.721984
# 1632  일원본동  1.414364e+06   3080.902875  1.428718e+06   3112.170433
# 1633  일원1동  5.412808e+06  11790.699264  6.088078e+06  13261.637513
# 1634  일원2동  1.146674e+05    249.779649  1.012180e+05    220.482873
# 1635   수서동  1.062495e+07  23144.282970  1.108850e+07  24154.033838
#
#               3월가스        3월온실가스          4월가스       4월온실가스          5월가스  \
# 0     1.570709e+06   3421.469238  1.117806e+06  2434.912575  1.198502e+06
# 1     1.183125e+06   2577.196451  7.117657e+05  1550.436611  7.393899e+05
# 2     2.698417e+06   5877.951317  1.633553e+06  3558.363246  1.639096e+06
# 3     6.871323e+05   1496.777649  4.551528e+05   991.457622  3.575049e+05
# 4     9.475743e+05   2064.097668  6.912783e+05  1505.808885  5.646304e+05
# ...            ...           ...           ...          ...           ...
# 1631  9.470552e+05   2062.966915  7.984701e+05  1739.304465  4.683278e+05
# 1632  1.167777e+06   2543.763778  8.833753e+05  1924.253119  6.367511e+05
# 1633  3.773293e+06   8219.349795  1.165208e+06  2538.167401  2.947677e+05
# 1634  1.167477e+05    254.311091  9.315253e+04   202.913817  9.381813e+04
# 1635  9.748830e+06  21235.839652  2.215262e+06  4825.496522  8.022309e+05
#
#            5월온실가스          6월가스       6월온실가스          7월가스       7월온실가스  \
# 0     2610.693396  1.586075e+06  3454.940352  1.695213e+06  3692.676731
# 1     1610.610156  8.577629e+05  1868.461731  9.352972e+05  2037.354497
# 2     3570.436309  2.053234e+06  4472.550993  2.298793e+06  5007.452576
# 3      778.751495  3.965561e+05   863.816592  4.105893e+05   894.385235
# 4     1229.932206  5.352743e+05  1165.985934  5.227659e+05  1138.738925
# ...           ...           ...          ...           ...          ...
# 1631  1020.156726  3.034470e+05   660.997499  2.718180e+05   592.100237
# 1632  1387.032480  5.962614e+05  1298.834052  6.023391e+05  1312.073085
# 1    392.028485
# 2   1118.731860
# 3   1623.103155
# 4    456.611902
# 5    853.262297
# 6    249.124123
# 7    541.669686
# 8    350.767703
# 9    462.370650
# 10   359.016809
# 11   302.698390
# 12   392.875160
# 13   342.380650
# 14  1086.682834
# 15   162.015652

# %%
guro_y
# Out:
#      행정동           9월가스       9월온실가스          10월가스      10월온실가스  \
# 0   신도림동  331510.257541   722.127557  387783.596288   844.707561
# 1   구로1동  162546.178654   354.073735  299335.923434   652.042325
# 2   구로2동  298433.663573   650.076936  389140.709977   847.663757
# 3   구로3동  683740.092807  1489.388494  714546.345708  1556.493640
# 4   구로4동   93426.515081   203.510629  123860.895592   269.805727
# 5   구로5동  377477.858469   822.258611  506155.125290  1102.555821
# 6   고척1동  274676.791183   598.327430  311343.962877   678.199393
# 7   고척2동  190195.299304   414.301711  368226.907193   802.107298
# 8   개봉1동  114863.721578   250.207216  179005.429234   389.926859
# 9   개봉2동  211420.255220   460.535953  329455.986079   717.652746
# 10  개봉3동  135241.447796   294.595941  165175.647332   359.801496
# 11  오류1동  180892.315545   394.037056  221899.800464   483.363508
# 12  오류2동  188012.979118   409.547971  364594.102088   794.193973
# 13    항동   52295.772622   113.915686  105901.744780   230.685376
# 14  가리봉동            NaN          NaN            NaN          NaN
# 15   수궁동            NaN          NaN            NaN          NaN
#
#            11월가스      11월온실가스         12월가스      12월온실가스
# 0   9.565792e+05  2083.712933  1.838105e+06  4003.937457
# 1   6.356184e+05  1384.565092  1.139868e+06  2482.970491
# 2   7.199002e+05  1568.155823  1.147391e+06  2499.357510
# 3   1.263837e+06  2753.010968  1.881811e+06  4099.141988
# 4   2.730274e+05   594.734520  5.138114e+05  1119.233363
# 5   1.089248e+06  2372.704663  1.984358e+06  4322.520322
# 6   6.901168e+05  1503.278751  1.150204e+06  2505.485497
# 7   7.604024e+05  1656.381603  1.347584e+06  2935.437974
# 8   4.410182e+05   960.668375  7.575249e+05  1650.113564
# 9   8.596907e+05  1872.661117  1.453452e+06  3166.049389
# 10  4.673302e+05  1017.983595  8.345638e+05  1817.927305
# 11  5.593060e+05  1218.334194  9.919651e+05  2160.793912
# 12  7.492174e+05  1632.017456  1.267423e+06  2760.823496
# 13  1.460415e+05   318.121733  2.921909e+05   636.478287
# 14           NaN          NaN           NaN          NaN
# 15           NaN          NaN           NaN          NaN

# %%
### 9월까지는 데이터가 있구나!
add_y = pd.DataFrame(train_y[['9월가스','9월온실가스']])
train_x = pd.concat([train_x, add_y], axis=1)
train_y = train_y.drop(['9월가스','9월온실가스'], axis=1)

guro_add_y = pd.DataFrame(guro_y[['9월가스','9월온실가스']])
guro_x = pd.concat([guro_x, guro_add_y], axis=1)
guro_y = guro_y.drop(['9월가스','9월온실가스'], axis=1)

### 그냥 '행정동'이름도 일단은 제거!
train_x = train_x.drop(['행정동'], axis=1)
train_y = train_y.drop(['행정동'], axis=1)
guro_x = guro_x.drop(['행정동'], axis=1)
guro_y = guro_y.drop(['행정동'], axis=1)

# %%
train = pd.concat([train_x, train_y], axis=1)
train
# Out:
# 4      968.498268  7.381340e+05  1607.874514  1.172913e+06  2554.952624
# ...           ...           ...          ...           ...          ...
# 1631   711.439900  5.356916e+05  1166.895000  9.649698e+05  2101.990000
# 1632  1372.878000  5.057316e+05  1101.633000  8.371947e+05  1823.658000
# 1633   352.529400  4.319157e+05   940.840300  5.346132e+05  1164.546000
# 1634   137.453200  8.072367e+04   175.840100  7.872372e+04   171.483600
# 1635   277.829100  3.058170e+05   666.160100  9.760349e+05  2126.093000
#
# [1636 rows x 24 columns]

# %%
def objective_rf(trial):
    
    params = {
        'max_depth' : trial.suggest_int('max_depth',1, 10),
        'max_leaf_nodes' : trial.suggest_int('max_leaf_nodes', 2, 1000),
        'n_estimators' : trial.suggest_int('n_estimators', 100, 500)
    }
    
    kf = KFold(n_splits = 5)
    
    score = []
    
    for train_idx, valid_idx in kf.split(train_x):
        train_data = train.iloc[train_idx]
        valid_data = train.iloc[valid_idx]
        
        
        rf = RandomForestRegressor(**params)
        model = MultiOutputRegressor(estimator=rf)
        
        x_train = train_data.iloc[:,0:18]
        y_train = train_data.iloc[:,18:24]
        model.fit(x_train,y_train)
        
        x_valid = valid_data.iloc[:,0:18]
        y_valid = valid_data.iloc[:,18:24]
        preds = model.predict(x_valid)
        
        nrmse = nrmse_1(preds, y_valid)
        score.append(nrmse)
    
    total = sum(score)/len(score)
    
    return total

# %%
sampler=optuna.samplers.TPESampler(seed=42)
study=optuna.create_study(
    direction='minimize',
    sampler=sampler
)
study.optimize(objective_rf, n_trials=100)
print('Best Score:',study.best_value)
print('Best trial:',study.best_trial.params)
# Out:
# [I 2022-10-28 15:59:39,557] A new study created in memory with name: no-name-1502191a-5ba0-4c5f-a180-4cf1d09767bc
# [I 2022-10-28 16:00:29,375] Trial 0 finished with value: 1.9343047922090122 and parameters: {'max_depth': 4, 'max_leaf_nodes': 951, 'n_estimators': 393}. Best is trial 0 with value: 1.9343047922090122.
# [I 2022-10-28 16:00:57,223] Trial 1 finished with value: 1.8240014186724867 and parameters: {'max_depth': 6, 'max_leaf_nodes': 157, 'n_estimators': 162}. Best is trial 1 with value: 1.8240014186724867.
# [I 2022-10-28 16:01:15,007] Trial 2 finished with value: 3.2504054085606953 and parameters: {'max_depth': 1, 'max_leaf_nodes': 867, 'n_estimators': 341}. Best is trial 1 with value: 1.8240014186724867.
# [I 2022-10-28 16:02:42,676] Trial 3 finished with value: 1.8562639069819178 and parameters: {'max_depth': 8, 'max_leaf_nodes': 22, 'n_estimators': 488}. Best is trial 1 with value: 1.8240014186724867.
# [I 2022-10-28 16:03:30,898] Trial 4 finished with value: 1.7419096847045865 and parameters: {'max_depth': 9, 'max_leaf_nodes': 214, 'n_estimators': 172}. Best is trial 4 with value: 1.7419096847045865.
# [I 2022-10-28 16:03:57,239] Trial 5 finished with value: 2.3222011941265444 and parameters: {'max_depth': 2, 'max_leaf_nodes': 305, 'n_estimators': 310}. Best is trial 4 with value: 1.7419096847045865.
# [I 2022-10-28 16:04:53,312] Trial 6 finished with value: 1.8650891825827762 and parameters: {'max_depth': 5, 'max_leaf_nodes': 292, 'n_estimators': 345}. Best is trial 4 with value: 1.7419096847045865.
. Best is trial 82 with value: 1.712158913246908.
# [I 2022-10-28 18:00:44,236] Trial 90 finished with value: 1.7291233935139734 and parameters: {'max_depth': 10, 'max_leaf_nodes': 487, 'n_estimators': 423}. Best is trial 82 with value: 1.712158913246908.
# [I 2022-10-28 18:03:12,867] Trial 91 finished with value: 1.734216719411044 and parameters: {'max_depth': 10, 'max_leaf_nodes': 547, 'n_estimators': 500}. Best is trial 82 with value: 1.712158913246908.
# [I 2022-10-28 18:05:13,340] Trial 92 finished with value: 1.7185059968217273 and parameters: {'max_depth': 10, 'max_leaf_nodes': 401, 'n_estimators': 410}. Best is trial 82 with value: 1.712158913246908.
# [I 2022-10-28 18:07:04,502] Trial 93 finished with value: 1.7379631359217786 and parameters: {'max_depth': 9, 'max_leaf_nodes': 379, 'n_estimators': 409}. Best is trial 82 with value: 1.712158913246908.
# [I 2022-10-28 18:09:19,483] Trial 94 finished with value: 1.716374777993162 and parameters: {'max_depth': 10, 'max_leaf_nodes': 508, 'n_estimators': 451}. Best is trial 82 with value: 1.712158913246908.
# [I 2022-10-28 18:11:32,954] Trial 95 finished with value: 1.7307934837895502 and parameters: {'max_depth': 10, 'max_leaf_nodes': 275, 'n_estimators': 452}. Best is trial 82 with value: 1.712158913246908.
# [I 2022-10-28 18:13:31,049] Trial 96 finished with value: 1.7178015031742828 and parameters: {'max_depth': 10, 'max_leaf_nodes': 458, 'n_estimators': 400}. Best is trial 82 with value: 1.712158913246908.
# [I 2022-10-28 18:15:36,561] Trial 97 finished with value: 1.7251259235702032 and parameters: {'max_depth': 10, 'max_leaf_nodes': 454, 'n_estimators': 425}. Best is trial 82 with value: 1.712158913246908.
# [I 2022-10-28 18:17:46,472] Trial 98 finished with value: 1.7353883047055239 and parameters: {'max_depth': 9, 'max_leaf_nodes': 424, 'n_estimators': 464}. Best is trial 82 with value: 1.712158913246908.
# [I 2022-10-28 18:19:14,646] Trial 99 finished with value: 1.8036530941590712 and parameters: {'max_depth': 6, 'max_leaf_nodes': 399, 'n_estimators': 431}. Best is trial 82 with value: 1.712158913246908.
# Best Score: 1.712158913246908
# Best trial: {'max_depth': 10, 'max_leaf_nodes': 803, 'n_estimators': 439}

# %%
kf = KFold(n_splits = 5)

cnt = 1
nrmse = 0
total_nrmse = 0

for train_idx, valid_idx in kf.split(train_x):
    train_data = train.iloc[train_idx]
    valid_data = train.iloc[valid_idx]
    
    rf = RandomForestRegressor(**study.best_trial.params)
    
    model = MultiOutputRegressor(estimator=rf)
    
    x_train = train_data.iloc[:,0:18]
    y_train = train_data.iloc[:,18:24]
    model.fit(x_train,y_train)
        
    x_valid = valid_data.iloc[:,0:18]
    y_valid = valid_data.iloc[:,18:24]
    preds = model.predict(x_valid)
    
    fit_params = dict(eval_set = [(x_train, y_train)], eval_metric = 'rmse')
    
    nrmse = nrmse_1(preds, y_valid)
    
    print(cnt," 번째 모델 nrmse : ",nrmse)
    
    total_nrmse += nrmse
    cnt+=1



print('모델 nrmse 평균 : ',total_nrmse/5)
# Out:
# 1  번째 모델 nrmse :  1.4546006556507636
# 2  번째 모델 nrmse :  2.2087128097451183
# 3  번째 모델 nrmse :  1.5807766113130532
# 4  번째 모델 nrmse :  1.47284942168641
# 5  번째 모델 nrmse :  1.893931465227577
# 모델 nrmse 평균 :  1.7221741927245844

# %%
rf_guro = RandomForestRegressor(**study.best_trial.params)
model_guro_rf = MultiOutputRegressor(estimator=rf_guro)

# %%
model_guro_rf
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor(max_depth=10,
#                                                      max_leaf_nodes=803,
#                                                      n_estimators=439))

# %%
model_guro_rf.fit(train.iloc[train_idx].iloc[:,0:18], train.iloc[train_idx].iloc[:,18:24])
# Out:
# MultiOutputRegressor(estimator=RandomForestRegressor
# 7   351553.276102   765.787190  306243.064965   667.088126  248666.672854
# 8   276462.587007   602.217422  190443.201856   414.841716  161028.464037
# 9   342378.807425   745.802479  243259.143852   529.890486  212262.517401
# 10  353668.053364   770.393801  242049.190255   527.254848  164815.417633
# 11  282375.480278   615.097455  182956.102088   398.532595  138961.074246
# 12  356972.946636   777.592838  235106.002320   512.130528  180358.918794
# 13  267301.373550   582.261585  193977.812065   422.541144  157178.183295
# 14  607862.106729  1324.103760  577329.593968  1257.594901  498868.243619
# 15   78040.083527   169.994423   43252.392111    94.216524   74377.234339
#
#          8월온실가스           9월가스       9월온실가스
# 0    678.100243  331510.257541   722.127557
# 1    392.028485  162546.178654   354.073735
# 2   1118.731860  298433.663573   650.076936
# 3   1623.103155  683740.092807  1489.388494
# 4    456.611902   93426.515081   203.510629
# 5    853.262297  377477.858469   822.258611
# 6    249.124123  274676.791183   598.327430
# 7    541.669686  190195.299304   414.301711
# 8    350.767703  114863.721578   250.207216
# 9    462.370650  211420.255220   460.535953
# 10   359.016809  135241.447796   294.595941
# 11   302.698390  180892.315545   394.037056
# 12   392.875160  188012.979118   409.547971
# 13   342.380650   52295.772622   113.915686
# 14  1086.682834            NaN          NaN
# 15   162.015652            NaN          NaN

# %%
preds_rf = model_guro_rf.predict(guro_x) ### 값 변경 부분
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26708/2725800395.py in <module>
# ----> 1 preds_rf = model_guro_rf.predict(guro_x) ### 값 변경 부분
#
# ~\anaconda3\lib\site-packages\sklearn\multioutput.py in predict(self, X)
#     232             raise ValueError("The base estimator should implement a predict method")
#     233
# --> 234         y = Parallel(n_jobs=self.n_jobs)(
#     235             delayed(e.predict)(X) for e in self.estimators_
#     236         )
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1041             # remaining jobs.
#    1042             self._iterating = False
# -> 1043             if self.dispatch_one_batch(iterator):
#    1044                 self._iterating = self._original_iterator is not None
#    1045
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     115     def __call__(self, *args, **kwargs):
#     116         with config_context(**self.config):
# --> 117             return self.function(*args, **kwargs)
#     118
#     119
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     989         check_is_fitted(self)
#     990         # Check data
# --> 991         X = self._validate_X_predict(X)
#     992
#     993         # Assign chunk of trees to jobs
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _validate_X_predict(self, X)
#     603         Validate X whenever one tries to predict, apply, predict_proba."""
#     604         check_is_fitted(self)
# --> 605         X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr", reset=False)
#     606         if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     607             raise ValueError("No support for np.int64 index based sparse matrices")
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     575             raise ValueError("Validation should be done on X, y or both.")
#     576         elif not no_val_X and no_val_y:
# --> 577             X = check_array(X, input_name="X", **check_params)
#     578             out = X
#     579         elif no_val_X and not no_val_y:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     897
#     898         if force_all_finite:
# --> 899             _assert_all_finite(
#     900                 array,
#     901                 input_name=input_name,
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144                     "#estimators-that-handle-nan-values"
#     145                 )
# --> 146             raise ValueError(msg_err)
#     147
#     148     # for object dtype data, we only check for NaNs (GH-13254)
#
# ValueError: Input X contains NaN.
# RandomForestRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
guro_y.iloc[:,0] = preds_rf[:,0]
guro_y.iloc[:,1] = preds_rf[:,1]
guro_y.iloc[:,2] = preds_rf[:,2]
guro_y.iloc[:,3] = preds_rf[:,3]
guro_y.iloc[:,4] = preds_rf[:,4]
guro_y.iloc[:,5] = preds_rf[:,5]

# %%
guro_y

# %%
guro_2020 = pd.concat([guro_x, guro_y], axis=1)

guro_2020

# %%
guro_2020.to_csv('guro_2020_rf.csv', index=False, encoding="cp949")
